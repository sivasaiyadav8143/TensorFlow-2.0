# %% [markdown]
# <a href="https://colab.research.google.com/github/sivasaiyadav8143/TensorFlow-2.x/blob/main/Traffic_Sign_Images(CNN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# <table>
#   <tr><td>
#     <img src="https://upload.wikimedia.org/wikipedia/commons/b/b6/UK_traffic_sign_543.svg"
#          alt="Real Mona Lisa"  width="400">
#   </td></tr>
#   <tr><td align="center">
#     <b>Figure 1. Traffic Sign Classification-
#   </td></tr>
# </table>

# %% [markdown]
# - In this case study, you have been provided with images of traffic signs and the goal is to train a Deep Network to classify them
# - The dataset contains 43 different classes of images.
# - Classes are as listed below:
#   - ( 0, b'Speed limit (20km/h)') ( 1, b'Speed limit (30km/h)')
#   - ( 2, b'Speed limit (50km/h)') ( 3, b'Speed limit (60km/h)')
#   - (4, b'Speed limit (70km/h)') ( 5, b'Speed limit (80km/h)')
#   - ( 6, b'End of speed limit (80km/h)') ( 7, b'Speed limit (100km/h)')
#   - ( 8, b'Speed limit (120km/h)') ( 9, b'No passing')
#   - (10, b'No passing for vehicles over 3.5 metric tons')
#   - (11, b'Right-of-way at the next intersection') (12, b'Priority road')
#   - (13, b'Yield') (14, b'Stop') (15, b'No vehicles')
#   - (16, b'Vehicles over 3.5 metric tons prohibited') (17, b'No entry')
#   - (18, b'General caution') (19, b'Dangerous curve to the left')
#   - (20, b'Dangerous curve to the right') (21, b'Double curve')
#   - (22, b'Bumpy road') (23, b'Slippery road')
#   - (24, b'Road narrows on the right') (25, b'Road work')
#   - (26, b'Traffic signals') (27, b'Pedestrians') (28, b'Children crossing')
#   - (29, b'Bicycles crossing') (30, b'Beware of ice/snow')
#   - (31, b'Wild animals crossing')
#   - (32, b'End of all speed and passing limits') (33, b'Turn right ahead')
#   - (34, b'Turn left ahead') (35, b'Ahead only') (36, b'Go straight or right')
#   - (37, b'Go straight or left') (38, b'Keep right') (39, b'Keep left')
#   - (40, b'Roundabout mandatory') (41, b'End of no passing')
#   - (42, b'End of no passing by vehicles over 3.5 metric tons')
# - The network used is called LeNet that was presented by Yann LeCun http://yann.lecun.com/exdb/publis/pdf/lecun-01a.pdf
# - Citation
# J. Stallkamp, M. Schlipsing, J. Salmen, and C. Igel. The German Traffic Sign Recognition Benchmark: A multi-class classification competition. In Proceedings of the IEEE International Joint Conference on Neural Networks, pages 1453–1460. 2011.
# @inproceedings{Stallkamp-IJCNN-2011, author = {Johannes Stallkamp and Marc Schlipsing and Jan Salmen and Christian Igel}, booktitle = {IEEE International Joint Conference on Neural Networks}, title = {The {G}erman {T}raffic {S}ign {R}ecognition {B}enchmark: A multi-class classification competition}, year = {2011}, pages = {1453--1460} }

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # STEP #0: IMPORT LIBRARIES

# %%
import matplotlib.pyplot as plt
import os
import PIL
from tensorflow.keras import layers
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle

# %% [markdown]
# # STEP #1: IMPORT DATASETS AND NORMALIZE IT

# %%
with open("/content/drive/MyDrive/Data/traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("/content/drive/MyDrive/Data/traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("/content/drive/MyDrive/Data/traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %% [markdown]
# # STEP #2: VISUALIZE DATASET

# %%
i = 3100
plt.imshow(X_train[i])
y_train[i]
# Out:
# 1

# %%
i = 3001
plt.imshow(X_validation[i])
y_validation[i]
# Out:
# 7

# %%
i = 2100
plt.imshow(X_test[i])
y_test[i]
# Out:
# 29

# %% [markdown]
# # STEP #3: DATA PREPARATION

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)
X_test_gray = np.sum(X_test/3, axis = 3, keepdims = True)
X_validation_gray = np.sum(X_validation/3, axis = 3, keepdims = True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_test_gray.shape
# Out:
# (12630, 32, 32, 1)

# %%
X_validation_gray.shape
# Out:
# (4410, 32, 32, 1)

# %%
X_train_gray_norm = (X_train_gray - 128)/128
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
X_train_gray_norm
# Out:
# array([[[[ 0.203125  ],
#          [ 0.21354167],
#          [ 0.2109375 ],
#          ...,
#          [-0.62760417],
#          [-0.62760417],
#          [-0.62760417]],
#
#         [[ 0.21875   ],
#          [ 0.20572917],
#          [ 0.22135417],
#          ...,
#          [-0.65104167],
#          [-0.65104167],
#          [-0.65104167]],
#
#         [[ 0.2265625 ],
#          [ 0.203125  ],
#          [ 0.2109375 ],
#          ...,
#          [-0.65885417],
#          [-0.6484375 ],
#          [-0.63020833]],
#
#         ...,
#
#         [[-0.59375   ],
#          [-0.62760417],
#          [-0.65364583],
#          ...,
#          [-0.5703125 ],
#          [-0.58854167],
#          [-0.59114583]],
#
#         [[-0.640625  ],
#          [-0.6640625 ],
#          [-0.65885417],
#          ...,
#          [-0.40104167],
#          [-0.44270833],
#          [-0.44010417]],
#
#         [[-0.65364583],
#          [-0.67447917],
#          [-0.60677083],
#          ...,
#          [-0.34895833],
#          [-0.36197917],
#          [-0.45052083]]],
#
#
#        [[[-0.7578125 ],
#          [-0.796875  ],
#          [-0.77864583],
#          ...,
#          [-0.67708333],
#          [-0.6875    ],
#          [-0.73697917]],
#
#         [[-0.78385417],
#          [-0.79166667],
#          [-0.7578125 ],
#          ...,
#          [-0.70833333],
#          [-0.7109375 ],
#          [-0.72916667]],
#
#         [[-0.79427083],
#          [-0.8046875 ],
#          [-0.79166667],
#          ...,
#          [-0.72916667],
#          [-0.75260417],
#          [-0.75260417]],
#
#         ...,
#
#         [[-0.63020833],
#          [-0.63541667],
#          [-0.63541667],
#          ...,
#          [-0.78645833],
#          [-0.72916667],
#          [-0.71614583]],
#
#         [[-0.64322917],
#          [-0.640625  ],
#          [-0.640625  ],
#          ...,
#          [-0.7890625 ],
#          [-0.72916667],
#          [-0.72395833]],
#
#         [[-0.01041667],
#          [ 0.01822917],
#          [-0.0234375 ],
#          ...,
#          [-0.79947917],
#          [-0.72916667],
#          [-0.72395833]]],
#
#
#        [[[-0.74739583],
#          [-0.75520833],
#          [-0.7578125 ],
#          ...,
#          [-0.796875  ],
#          [-0.79427083],
#          [-0.79427083]],
#
#         [[-0.75      ],
#          [-0.75      ],
#          [-0.76302083],
#          ...,
#          [-0.79166667],
#          [-0.80208333],
#          [-0.7890625 ]],
#
#         [[-0.7265625 ],
#          [-0.72395833],
#          [-0.75      ],
#          ...,
#          [-0.78125   ],
#          [-0.796875  ],
#          [-0.7890625 ]],
#
#         ...,
#
#         [[-0.765625  ],
#          [-0.76822917],
#          [-0.76822917],
#          ...,
#          [-0.765625  ],
#          [-0.77083333],
#          [-0.78125   ]],
#
#         [[-0.77604167],
#          [-0.77864583],
#          [-0.77604167],
#          ...,
#          [-0.77864583],
#          [-0.78125   ],
#          [-0.7890625 ]],
#
#         [[-0.76041667],
#          [-0.76041667],
#          [-0.76822917],
#          ...,
#          [-0.78385417],
#          [-0.78385417],
#          [-0.78125   ]]],
#
#
#        ...,
#
#
#        [[[-0.83854167],
#          [-0.8203125 ],
#          [-0.83333333],
#          ...,
#          [-0.85677083],
#          [-0.84635417],
#          [-0.8515625 ]],
#
#         [[-0.84635417],
#          [-0.83072917],
#          [-0.8359375 ],
#          ...,
#          [-0.8671875 ],
#          [-0.85416667],
#          [-0.85677083]],
#
#         [[-0.84895833],
#          [-0.8359375 ],
#          [-0.84375   ],
#          ...,
#          [-0.86979167],
#          [-0.85416667],
#          [-0.859375  ]],
#
#         ...,
#
#         [[-0.8515625 ],
#          [-0.85416667],
#          [-0.84895833],
#          ...,
#          [-0.8828125 ],
#          [-0.859375  ],
#          [-0.859375  ]],
#
#         [[-0.859375  ],
#          [-0.859375  ],
#          [-0.85416667],
#          ...,
#          [-0.86979167],
#          [-0.859375  ],
#          [-0.85416667]],
#
#         [[-0.859375  ],
#          [-0.86458333],
#          [-0.86458333],
#          ...,
#          [-0.88020833],
#          [-0.86458333],
#          [-0.859375  ]]],
#
#
#        [[[-0.671875  ],
#          [-0.68489583],
#          [-0.61458333],
#          ...,
#          [-0.6015625 ],
#          [-0.6640625 ],
#          [-0.55989583]],
#
#         [[-0.72135417],
#          [-0.72916667],
#          [-0.67708333],
#          ...,
#          [-0.56770833],
#          [-0.6015625 ],
#          [-0.59635417]],
#
#         [[-0.6796875 ],
#          [-0.70052083],
#          [-0.70572917],
#          ...,
#          [-0.56510417],
#          [-0.54427083],
#          [-0.5625    ]],
#
#         ...,
#
#         [[-0.62239583],
#          [-0.67447917],
#          [-0.70833333],
#          ...,
#          [-0.76302083],
#          [-0.74739583],
#          [-0.71614583]],
#
#         [[-0.6875    ],
#          [-0.70572917],
#          [-0.73177083],
#          ...,
#          [-0.74739583],
#          [-0.75520833],
#          [-0.72135417]],
#
#         [[-0.7265625 ],
#          [-0.69791667],
#          [-0.72395833],
#          ...,
#          [-0.65104167],
#          [-0.671875  ],
#          [-0.66927083]]],
#
#
#        [[[-0.60677083],
#          [-0.54427083],
#          [-0.50260417],
#          ...,
#          [-0.50520833],
#          [-0.50260417],
#          [-0.52864583]],
#
#         [[-0.57552083],
#          [-0.5625    ],
#          [-0.48697917],
#          ...,
#          [-0.51822917],
#          [-0.546875  ],
#          [-0.52864583]],
#
#         [[-0.52083333],
#          [-0.57291667],
#          [-0.5078125 ],
#          ...,
#          [-0.5       ],
#          [-0.515625  ],
#          [-0.5234375 ]],
#
#         ...,
#
#         [[-0.5       ],
#          [-0.51302083],
#          [-0.45052083],
#          ...,
#          [-0.51302083],
#          [-0.5625    ],
#          [-0.49479167]],
#
#         [[-0.48958333],
#          [-0.46354167],
#          [-0.44791667],
#          ...,
#          [-0.515625  ],
#          [-0.5703125 ],
#          [-0.5       ]],
#
#         [[-0.5078125 ],
#          [-0.53385417],
#          [-0.47916667],
#          ...,
#          [-0.48697917],
#          [-0.546875  ],
#          [-0.53645833]]]])

# %%
i = 60
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %%
i = 610
plt.imshow(X_test_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_test[i])
plt.figure()
plt.imshow(X_test_gray_norm[i].squeeze(), cmap = 'gray')

# %%
i = 500
plt.imshow(X_validation_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_validation[i])
plt.figure()
plt.imshow(X_validation_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# # STEP#4: MODEL TRAINING

# %% [markdown]
# The model consists of the following layers:
#
# - STEP 1: THE FIRST CONVOLUTIONAL LAYER #1
#     - Input = 32x32x1
#     - Output = 28x28x6
#     - Output = (Input-filter+1)/Stride* => (32-5+1)/1=28
#     - Used a 5x5 Filter with input depth of 3 and output depth of 6
#     - Apply a RELU Activation function to the output
#     - pooling for input, Input = 28x28x6 and Output = 14x14x6
#
#
#     * Stride is the amount by which the kernel is shifted when the kernel is passed over the image.
#
# - STEP 2: THE SECOND CONVOLUTIONAL LAYER #2
#     - Input = 14x14x6
#     - Output = 10x10x16
#     - Layer 2: Convolutional layer with Output = 10x10x16
#     - Output = (Input-filter+1)/strides => 10 = 14-5+1/1
#     - Apply a RELU Activation function to the output
#     - Pooling with Input = 10x10x16 and Output = 5x5x16
#
# - STEP 3: FLATTENING THE NETWORK
#     - Flatten the network with Input = 5x5x16 and Output = 400
#
# - STEP 4: FULLY CONNECTED LAYER
#     - Layer 3: Fully Connected layer with Input = 400 and Output = 120
#     - Apply a RELU Activation function to the output
#
# - STEP 5: ANOTHER FULLY CONNECTED LAYER
#     - Layer 4: Fully Connected Layer with Input = 120 and Output = 84
#     - Apply a RELU Activation function to the output
#
# - STEP 6: FULLY CONNECTED LAYER
#     - Layer 5: Fully Connected layer with Input = 84 and Output = 43

# %%
from tensorflow.keras import datasets, layers, models

LeNet = models.Sequential()

LeNet.add(layers.Conv2D(6, (5,5), activation = 'relu', input_shape = (32,32,1)))
LeNet.add(layers.AveragePooling2D())


LeNet.add(layers.Conv2D(16, (5,5), activation = 'relu'))
LeNet.add(layers.AveragePooling2D())

LeNet.add(layers.Flatten())

LeNet.add(layers.Dense(120, activation = 'relu'))

LeNet.add(layers.Dense(84, activation = 'relu'))

LeNet.add(layers.Dense(43, activation = 'softmax'))
LeNet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                3655
# =================================================================
# Total params: 64,511
# Trainable params: 64,511
# Non-trainable params: 0
# _________________________________________________________________

# %%
LeNet.compile(optimizer = 'Adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
history = LeNet.fit(X_train_gray_norm,
                 y_train, 
                 batch_size = 500,
                 epochs = 50,
                 verbose = 1,
                 validation_data = (X_validation_gray_norm, y_validation))
# Out:
# Epoch 1/50
# 70/70 [==============================] - 8s 10ms/step - loss: 3.4645 - accuracy: 0.1072 - val_loss: 2.6324 - val_accuracy: 0.3283
# Epoch 2/50
# 70/70 [==============================] - 0s 5ms/step - loss: 1.9446 - accuracy: 0.4756 - val_loss: 1.3227 - val_accuracy: 0.6093
# Epoch 3/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.9766 - accuracy: 0.7290 - val_loss: 0.9077 - val_accuracy: 0.7413
# Epoch 4/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.6698 - accuracy: 0.8134 - val_loss: 0.7866 - val_accuracy: 0.7889
# Epoch 5/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.5011 - accuracy: 0.8670 - val_loss: 0.6576 - val_accuracy: 0.8118
# Epoch 6/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.4076 - accuracy: 0.8938 - val_loss: 0.6254 - val_accuracy: 0.8188
# Epoch 7/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3388 - accuracy: 0.9136 - val_loss: 0.6393 - val_accuracy: 0.8163
# Epoch 8/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.2934 - accuracy: 0.9258 - val_loss: 0.6120 - val_accuracy: 0.8392
# Epoch 9/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.2545 - accuracy: 0.9358 - val_loss: 0.5932 - val_accuracy: 0.8531
# Epoch 10/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.2228 - accuracy: 0.9451 - val_loss: 0.5790 - val_accuracy: 0.8565
# Epoch 11/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.1997 - accuracy: 0.9495 - val_loss: 0.5433 - val_accuracy: 0.8726
# Epoch 12/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.1744 - accuracy: 0.9589 - val_loss: 0.5551 - val_accuracy: 0.8667
# Epoch 13/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.1531 - accuracy: 0.9648 - val_loss: 0.6019 - val_accuracy: 0.8580
# Epoch 14/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.1428 - accuracy: 0.9652 - val_loss: 0.5535 - val_accuracy: 0.8737
# Epoch 15/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.1271 - accuracy: 0.9704 - val_loss: 0.5289 - val_accuracy: 0.8741
# Epoch 16/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.1179 - accuracy: 0.9724 - val_loss: 0.5402 - val_accuracy: 0.8717
# Epoch 17/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0996 - accuracy: 0.9762 - val_loss: 0.5410 - val_accuracy: 0.8776
# Epoch 18/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0918 - accuracy: 0.9788 - val_loss: 0.5669 - val_accuracy: 0.8751
# Epoch 19/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0873 - accuracy: 0.9803 - val_loss: 0.6373 - val_accuracy: 0.8717
# Epoch 20/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0784 - accuracy: 0.9821 - val_loss: 0.6167 - val_accuracy: 0.8728
# Epoch 21/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0709 - accuracy: 0.9837 - val_loss: 0.6215 - val_accuracy: 0.8762
# Epoch 22/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0670 - accuracy: 0.9846 - val_loss: 0.6228 - val_accuracy: 0.8744
# Epoch 23/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0610 - accuracy: 0.9867 - val_loss: 0.5822 - val_accuracy: 0.8805
# Epoch 24/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0588 - accuracy: 0.9866 - val_loss: 0.5706 - val_accuracy: 0.8841
# Epoch 25/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0525 - accuracy: 0.9881 - val_loss: 0.6180 - val_accuracy: 0.8778
# Epoch 26/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0450 - accuracy: 0.9894 - val_loss: 0.6419 - val_accuracy: 0.8875
# Epoch 27/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0466 - accuracy: 0.9887 - val_loss: 0.6022 - val_accuracy: 0.8798
# Epoch 28/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0414 - accuracy: 0.9902 - val_loss: 0.6568 - val_accuracy: 0.8832
# Epoch 29/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0382 - accuracy: 0.9909 - val_loss: 0.6548 - val_accuracy: 0.8834
# Epoch 30/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0326 - accuracy: 0.9928 - val_loss: 0.6427 - val_accuracy: 0.8866
# Epoch 31/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0311 - accuracy: 0.9929 - val_loss: 0.6999 - val_accuracy: 0.8807
# Epoch 32/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0319 - accuracy: 0.9925 - val_loss: 0.6668 - val_accuracy: 0.8794
# Epoch 33/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0267 - accuracy: 0.9934 - val_loss: 0.7060 - val_accuracy: 0.8735
# Epoch 34/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0248 - accuracy: 0.9945 - val_loss: 0.8026 - val_accuracy: 0.8676
# Epoch 35/50
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0249 - accuracy: 0.9940 - val_loss: 0.6929 - val_accuracy: 0.8807
# Epoch 36/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0261 - accuracy: 0.9940 - val_loss: 0.7404 - val_accuracy: 0.8717
# Epoch 37/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0265 - accuracy: 0.9930 - val_loss: 0.7376 - val_accuracy: 0.8744
# Epoch 38/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0226 - accuracy: 0.9940 - val_loss: 0.7694 - val_accuracy: 0.8841
# Epoch 39/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9967 - val_loss: 0.7146 - val_accuracy: 0.8764
# Epoch 40/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 0.9968 - val_loss: 0.8043 - val_accuracy: 0.8850
# Epoch 41/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.9956 - val_loss: 0.7588 - val_accuracy: 0.8810
# Epoch 42/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 0.9968 - val_loss: 0.7570 - val_accuracy: 0.8787
# Epoch 43/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0221 - accuracy: 0.9943 - val_loss: 0.7738 - val_accuracy: 0.8753
# Epoch 44/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 0.9973 - val_loss: 0.7813 - val_accuracy: 0.8805
# Epoch 45/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0100 - accuracy: 0.9979 - val_loss: 0.7703 - val_accuracy: 0.8907
# Epoch 46/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 0.9983 - val_loss: 0.8861 - val_accuracy: 0.8853
# Epoch 47/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 0.9987 - val_loss: 0.9200 - val_accuracy: 0.8769
# Epoch 48/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 0.9974 - val_loss: 0.9088 - val_accuracy: 0.8748
# Epoch 49/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0215 - accuracy: 0.9936 - val_loss: 0.8661 - val_accuracy: 0.8819
# Epoch 50/50
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 0.9955 - val_loss: 0.7928 - val_accuracy: 0.8868

# %% [markdown]
# # STEP#5: MODEL EVALUATION

# %%
score = LeNet.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 395/395 [==============================] - 1s 2ms/step - loss: 1.1551 - accuracy: 0.8877
# Test Accuracy: 0.8877276182174683

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

# %%
predicted_classes = LeNet.predict_classes(X_test_gray_norm)
y_true = y_test
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25, 25))
sns.heatmap(cm, annot = True)

# %%
L = 7
W = 7

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)
