# %% [markdown]
# <a href="https://colab.research.google.com/github/sivasaiyadav8143/TensorFlow-2.x/blob/main/Predict_House_Prices_using_ANN(Regression).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# <table>
#   <tr><td>
#     <img src="https://upload.wikimedia.org/wikipedia/commons/0/04/Enlisted_Housing%2C_Fort_Belvior.jpg"
#          alt="Fashion MNIST sprite"  width="600">
#   </td></tr>
#   <tr><td align="center">
#     <b>Figure 1. House Price Predictions
#   </td></tr>
# </table>

# %% [markdown]
# ---
#
# * Dataset includes house sale prices for King County in USA.
# * Homes that are sold in the time period: May, 2014 and May, 2015.
# * Data Source: https://www.kaggle.com/harlfoxem/housesalesprediction
# * Columns:
#
# > 1. ida: notation for a house
# 2. date: Date house was sold
# 3. price: Price is prediction target
# 4. bedrooms: Number of Bedrooms/House
# 5. bathrooms: Number of bathrooms/House
# 6. sqft_living: square footage of the home
# 7. sqft_lot: square footage of the lot
# 8. floors: Total floors (levels) in house
# 9. waterfront: House which has a view to a waterfront
# 10. view: Has been viewed
# 11. condition: How good the condition is ( Overall )
# 12. grade: overall grade given to the housing unit, based on King County grading system
# 13. sqft_abovesquare: footage of house apart from basement
# 14. sqft_basement: square footage of the basement
# 15. yr_built: Built Year
# 16. yr_renovated: Year when house was renovated
# 17. zipcode: zip
# 18. lat: Latitude coordinate
# 19. long: Longitude coordinate
# 20. sqft_living15: Living room area in 2015(implies-- some renovations)
# 21. sqft_lot15: lotSize area in 2015(implies-- some renovations)
#
#
#
#
# ---

# %% [markdown]
# # STEP #0: IMPORT LIBRARIES

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # STEP #1: IMPORT DATASETS

# %%
# You will need to mount your drive using the following commands:
# For more information regarding mounting, please check this out: https://stackoverflow.com/questions/46986398/import-data-into-google-colaboratory

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# You have to include the full link to the csv file containing your dataset
house_df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/kc_house_data.csv', encoding = 'ISO-8859-1')

# %%
house_df.head()
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
house_df.tail(5)
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [5 rows x 21 columns]

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# # STEP #2: VISUALIZE DATASET

# %%
sns.scatterplot(x = 'sqft_living', y = 'price', data = house_df)

# %%
f, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(house_df.corr(), annot = True)

# %%
house_df.hist(bins = 20, figsize = (20,20), color = 'g')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbcbc18bcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbcbc274518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbcbbe48320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbcbbd89898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbcbbd2fe10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbcba4dd3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbcba505940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbcba4adef0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbcba4adf28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbcba4859e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbcba42ef60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbcba3df518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbcba405a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbcba3b8048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbcba35f5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbcba387b38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbcba33a0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbcba2e0668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbcba309be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbcba2ba198>]],
#       dtype=object)

# %%
sns.pairplot(house_df)

# %% [markdown]
# # STEP #3: CREATE TESTING AND TRAINING DATASET/DATA CLEANING

# %%
selected_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqft_basement']

# %%
X = house_df[selected_features]

# %%
X.head()
# Out:
#    bedrooms  bathrooms  sqft_living  ...  floors  sqft_above  sqft_basement
# 0         3       1.00         1180  ...     1.0        1180              0
# 1         3       2.25         2570  ...     2.0        2170            400
# 2         2       1.00          770  ...     1.0         770              0
# 3         4       3.00         1960  ...     1.0        1050            910
# 4         3       2.00         1680  ...     1.0        1680              0
#
# [5 rows x 7 columns]

# %%
y = house_df['price']

# %%
y.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
X.shape
# Out:
# (21613, 7)

# %%
y.shape
# Out:
# (21613,)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled[0]
# Out:
# array([0.09090909, 0.125     , 0.06716981, 0.00310751, 0.        ,
#        0.09758772, 0.        ])

# %%
X_scaled.shape
# Out:
# (21613, 7)

# %%
scaler.data_max_
# Out:
# array([3.300000e+01, 8.000000e+00, 1.354000e+04, 1.651359e+06,
#        3.500000e+00, 9.410000e+03, 4.820000e+03])

# %%
scaler.data_min_
# Out:
# array([  0.,   0., 290., 520.,   1., 290.,   0.])

# %%
y = y.values.reshape(-1,1)

# %%
y_scaled = scaler.fit_transform(y)

# %%
y_scaled[0]
# Out:
# array([0.01926557])

# %% [markdown]
# # STEP#4: TRAINING THE MODEL

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.25)

# %%
X_train.shape
# Out:
# (16209, 7)

# %%
X_test.shape
# Out:
# (5404, 7)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=100, activation='relu', input_shape=(7, )))
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=1, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               800
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 21,101
# Trainable params: 21,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 100, batch_size = 50, validation_split = 0.2)
# Out:
# Epoch 1/100
# 260/260 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 2/100
# 260/260 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 3/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.9329e-04 - val_loss: 0.0011
# Epoch 4/100
# 260/260 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 5/100
# 260/260 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 6/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.7311e-04 - val_loss: 0.0011
# Epoch 7/100
# 260/260 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 8/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.6361e-04 - val_loss: 0.0011
# Epoch 9/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.5600e-04 - val_loss: 0.0012
# Epoch 10/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.7440e-04 - val_loss: 0.0011
# Epoch 11/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.5318e-04 - val_loss: 0.0011
# Epoch 12/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.6417e-04 - val_loss: 0.0011
# Epoch 13/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.4613e-04 - val_loss: 0.0011
# Epoch 14/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.4745e-04 - val_loss: 0.0011
# Epoch 15/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.4414e-04 - val_loss: 0.0011
# Epoch 16/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.3294e-04 - val_loss: 0.0011
# Epoch 17/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.5002e-04 - val_loss: 0.0011
# Epoch 18/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.1756e-04 - val_loss: 0.0011
# Epoch 19/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.4120e-04 - val_loss: 0.0011
# Epoch 20/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.0998e-04 - val_loss: 0.0011
# Epoch 21/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.2028e-04 - val_loss: 0.0011
# Epoch 22/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.2713e-04 - val_loss: 0.0011
# Epoch 23/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.4448e-04 - val_loss: 0.0011
# Epoch 24/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.2837e-04 - val_loss: 0.0011
# Epoch 25/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.1346e-04 - val_loss: 0.0011
# Epoch 26/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.0150e-04 - val_loss: 0.0011
# Epoch 27/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.0215e-04 - val_loss: 0.0010
# Epoch 28/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.0730e-04 - val_loss: 0.0011
# Epoch 29/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.2576e-04 - val_loss: 0.0011
# Epoch 30/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.0143e-04 - val_loss: 0.0011
# Epoch 31/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.1513e-04 - val_loss: 0.0011
# Epoch 32/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.0529e-04 - val_loss: 0.0011
# Epoch 33/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.1169e-04 - val_loss: 0.0011
# Epoch 34/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.2370e-04 - val_loss: 0.0011
# Epoch 35/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.1125e-04 - val_loss: 0.0011
# Epoch 36/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.3211e-04 - val_loss: 0.0010
# Epoch 37/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.9510e-04 - val_loss: 0.0010
# Epoch 38/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.0485e-04 - val_loss: 0.0011
# Epoch 39/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.0174e-04 - val_loss: 0.0011
# Epoch 40/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.9423e-04 - val_loss: 0.0010
# Epoch 41/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.8728e-04 - val_loss: 0.0011
# Epoch 42/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.9709e-04 - val_loss: 0.0011
# Epoch 43/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.0130e-04 - val_loss: 0.0011
# Epoch 44/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.9016e-04 - val_loss: 0.0011
# Epoch 45/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.0971e-04 - val_loss: 0.0011
# Epoch 46/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.8592e-04 - val_loss: 0.0010
# Epoch 47/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.8746e-04 - val_loss: 0.0011
# Epoch 48/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.8708e-04 - val_loss: 0.0011
# Epoch 49/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.8348e-04 - val_loss: 0.0011
# Epoch 50/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.8627e-04 - val_loss: 0.0012
# Epoch 51/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.9124e-04 - val_loss: 0.0011
# Epoch 52/100
# 260/260 [==============================] - 0s 2ms/step - loss: 9.0861e-04 - val_loss: 0.0011
# Epoch 53/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.2281e-04 - val_loss: 0.0011
# Epoch 54/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.9274e-04 - val_loss: 0.0011
# Epoch 55/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.7321e-04 - val_loss: 0.0011
# Epoch 56/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.8389e-04 - val_loss: 0.0011
# Epoch 57/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.7313e-04 - val_loss: 0.0011
# Epoch 58/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.8012e-04 - val_loss: 0.0014
# Epoch 59/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.8896e-04 - val_loss: 0.0011
# Epoch 60/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.7979e-04 - val_loss: 0.0011
# Epoch 61/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.7328e-04 - val_loss: 0.0011
# Epoch 62/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.8185e-04 - val_loss: 0.0011
# Epoch 63/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.8120e-04 - val_loss: 0.0012
# Epoch 64/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.6613e-04 - val_loss: 0.0012
# Epoch 65/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.7183e-04 - val_loss: 0.0011
# Epoch 66/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.8199e-04 - val_loss: 0.0011
# Epoch 67/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.7278e-04 - val_loss: 0.0011
# Epoch 68/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.6815e-04 - val_loss: 0.0013
# Epoch 69/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.7125e-04 - val_loss: 0.0011
# Epoch 70/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.5570e-04 - val_loss: 0.0011
# Epoch 71/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.6505e-04 - val_loss: 0.0011
# Epoch 72/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.5937e-04 - val_loss: 0.0013
# Epoch 73/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.5732e-04 - val_loss: 0.0011
# Epoch 74/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.6475e-04 - val_loss: 0.0011
# Epoch 75/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.6008e-04 - val_loss: 0.0012
# Epoch 76/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.5667e-04 - val_loss: 0.0011
# Epoch 77/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.6514e-04 - val_loss: 0.0011
# Epoch 78/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.5301e-04 - val_loss: 0.0011
# Epoch 79/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.5754e-04 - val_loss: 0.0011
# Epoch 80/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.4970e-04 - val_loss: 0.0011
# Epoch 81/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.5843e-04 - val_loss: 0.0011
# Epoch 82/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.5303e-04 - val_loss: 0.0011
# Epoch 83/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.5149e-04 - val_loss: 0.0011
# Epoch 84/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.4623e-04 - val_loss: 0.0011
# Epoch 85/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.5442e-04 - val_loss: 0.0012
# Epoch 86/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.4738e-04 - val_loss: 0.0011
# Epoch 87/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.4753e-04 - val_loss: 0.0011
# Epoch 88/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.3783e-04 - val_loss: 0.0012
# Epoch 89/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.4138e-04 - val_loss: 0.0011
# Epoch 90/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.4911e-04 - val_loss: 0.0011
# Epoch 91/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.3554e-04 - val_loss: 0.0011
# Epoch 92/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.5388e-04 - val_loss: 0.0011
# Epoch 93/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.3880e-04 - val_loss: 0.0012
# Epoch 94/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.5346e-04 - val_loss: 0.0011
# Epoch 95/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.2434e-04 - val_loss: 0.0011
# Epoch 96/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.3649e-04 - val_loss: 0.0011
# Epoch 97/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.3274e-04 - val_loss: 0.0011
# Epoch 98/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.3897e-04 - val_loss: 0.0012
# Epoch 99/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.3901e-04 - val_loss: 0.0013
# Epoch 100/100
# 260/260 [==============================] - 0s 2ms/step - loss: 8.4754e-04 - val_loss: 0.0012

# %% [markdown]
# # STEP#5: EVALUATING THE MODEL

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
# 'bedrooms','bathrooms','sqft_living','sqft_lot','floors', 'sqft_above', 'sqft_basement'
X_test_1 = np.array([[ 4, 3, 1960, 5000, 1, 2000, 3000 ]])

scaler_1 = MinMaxScaler()
X_test_scaled_1 = scaler_1.fit_transform(X_test_1)

y_predict_1 = model.predict(X_test_scaled_1)

y_predict_1 = scaler.inverse_transform(y_predict_1)
y_predict_1
# Out:
# array([[213333.34]], dtype=float32)

# %%
y_predict = model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')

# %%
y_predict_orig = scaler.inverse_transform(y_predict)
y_test_orig = scaler.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
plt.xlim(0, 5000000)
plt.ylim(0, 3000000)
# Out:
# (0.0, 3000000.0)

# %%
k = X_test.shape[1]
n = len(X_test)
n
# Out:
# 5404

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 245156.343
# MSE = 60101632611.98899
# MAE = 160807.4131285853
# R2 = 0.594455667181469
# Adjusted R2 = 0.5939295718646177

# %% [markdown]
# # LET'S INCREASE THE NUMBER OF FEATURES (INDEPENDANT VARIABLES) AND RETRAIN THE EXACT SAME MODEL

# %%
selected_features = ['bedrooms','bathrooms','sqft_living','sqft_lot','floors', 'sqft_above', 'sqft_basement', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'yr_built', 
'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

X = house_df[selected_features]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
y = house_df['price']

# %%
y = y.values.reshape(-1,1)
y_scaled = scaler.fit_transform(y)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.25)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=100, activation='relu', input_shape=(19, )))
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=1, activation='linear'))

# %%
model.compile(optimizer='Adam', loss='mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 100, batch_size = 50, validation_split = 0.2)
# Out:
# Epoch 1/100
# 260/260 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 6.2215e-04
# Epoch 2/100
# 260/260 [==============================] - 0s 2ms/step - loss: 6.0169e-04 - val_loss: 4.9458e-04
# Epoch 3/100
# 260/260 [==============================] - 0s 2ms/step - loss: 5.5355e-04 - val_loss: 5.8955e-04
# Epoch 4/100
# 260/260 [==============================] - 0s 2ms/step - loss: 5.0355e-04 - val_loss: 5.2384e-04
# Epoch 5/100
# 260/260 [==============================] - 0s 2ms/step - loss: 4.2732e-04 - val_loss: 4.3561e-04
# Epoch 6/100
# 260/260 [==============================] - 0s 2ms/step - loss: 4.1876e-04 - val_loss: 4.2293e-04
# Epoch 7/100
# 260/260 [==============================] - 0s 2ms/step - loss: 3.8434e-04 - val_loss: 4.2175e-04
# Epoch 8/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.6465e-04 - val_loss: 4.5048e-04
# Epoch 9/100
# 260/260 [==============================] - 0s 2ms/step - loss: 3.5166e-04 - val_loss: 3.8569e-04
# Epoch 10/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.6854e-04 - val_loss: 3.8830e-04
# Epoch 11/100
# 260/260 [==============================] - 0s 2ms/step - loss: 3.3627e-04 - val_loss: 3.9214e-04
# Epoch 12/100
# 260/260 [==============================] - 0s 2ms/step - loss: 3.8722e-04 - val_loss: 3.8125e-04
# Epoch 13/100
# 260/260 [==============================] - 0s 2ms/step - loss: 3.2309e-04 - val_loss: 3.5948e-04
# Epoch 14/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.2744e-04 - val_loss: 3.3819e-04
# Epoch 15/100
# 260/260 [==============================] - 0s 2ms/step - loss: 3.0587e-04 - val_loss: 3.2788e-04
# Epoch 16/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.8692e-04 - val_loss: 3.2012e-04
# Epoch 17/100
# 260/260 [==============================] - 0s 2ms/step - loss: 2.8511e-04 - val_loss: 3.8080e-04
# Epoch 18/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.8125e-04 - val_loss: 3.6768e-04
# Epoch 19/100
# 260/260 [==============================] - 0s 2ms/step - loss: 2.8835e-04 - val_loss: 3.9959e-04
# Epoch 20/100
# 260/260 [==============================] - 0s 2ms/step - loss: 2.7887e-04 - val_loss: 3.4932e-04
# Epoch 21/100
# 260/260 [==============================] - 0s 2ms/step - loss: 2.7715e-04 - val_loss: 3.7655e-04
# Epoch 22/100
# 260/260 [==============================] - 0s 2ms/step - loss: 2.6882e-04 - val_loss: 3.4208e-04
# Epoch 23/100
# 260/260 [==============================] - 0s 2ms/step - loss: 2.7202e-04 - val_loss: 3.2862e-04
# Epoch 24/100
# 260/260 [==============================] - 0s 2ms/step - loss: 2.7266e-04 - val_loss: 4.5614e-04
# Epoch 25/100
# 260/260 [==============================] - 0s 2ms/step - loss: 2.5684e-04 - val_loss: 3.2275e-04
# Epoch 26/100
# 260/260 [==============================] - 0s 2ms/step - loss: 2.5554e-04 - val_loss: 3.5150e-04
# Epoch 27/100
# 260/260 [==============================] - 0s 2ms/step - loss: 2.6022e-04 - val_loss: 3.8101e-04
# Epoch 28/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.3995e-04 - val_loss: 3.2059e-04
# Epoch 29/100
# 260/260 [==============================] - 0s 2ms/step - loss: 2.6284e-04 - val_loss: 3.0806e-04
# Epoch 30/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.2715e-04 - val_loss: 3.7699e-04
# Epoch 31/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.3971e-04 - val_loss: 3.3336e-04
# Epoch 32/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.4140e-04 - val_loss: 3.3672e-04
# Epoch 33/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.3095e-04 - val_loss: 3.9180e-04
# Epoch 34/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.4016e-04 - val_loss: 4.3969e-04
# Epoch 35/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.1785e-04 - val_loss: 3.9349e-04
# Epoch 36/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.1867e-04 - val_loss: 3.0744e-04
# Epoch 37/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.1305e-04 - val_loss: 3.1821e-04
# Epoch 38/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.6744e-04 - val_loss: 4.3208e-04
# Epoch 39/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.4607e-04 - val_loss: 3.3091e-04
# Epoch 40/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.